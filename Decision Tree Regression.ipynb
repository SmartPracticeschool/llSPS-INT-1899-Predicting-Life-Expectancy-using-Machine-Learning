# %% [markdown]
# # Libraries

# %%
import pandas as pd
import types
from botocore.client import Config
import ibm_boto3
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Getting Data

# %%
def __iter__(self): return 0
client_a0d05a4099de4fb9959cc586a2ecfe6e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Mx7ITaaOwr8pENZj51RBT3y7P6e__LD41YyPsvN_DzKd',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')
body = client_a0d05a4099de4fb9959cc586a2ecfe6e.get_object(Bucket='lifeexpectancyprediction-donotdelete-pr-ikdrrtgelmi3ph',Key='LED.csv')['Body']
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
data = pd.read_csv(body)
print(data.shape)
data.head()
# Out:
# (2938, 22)
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
# ...

# %% [markdown]
# # Handling Data

# %%
c1=data['Country']
list1=c1.unique()
s1=c1.nunique()
l1=np.arange(s1)

# %%
c2=data['Status']
list2=c2.unique()
s2=c2.nunique()
l2=np.arange(s2)

# %%
for i in range(data.shape[0]):
    for j in range(list1.shape[0]):
        if(c1.iloc[i]==list1[j]):
            c1.iloc[i]=l1[j]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
for i in range(data.shape[0]):
    for j in range(list2.shape[0]):
        if(c2.iloc[i]==list2[j]):
            c2.iloc[i]=l2[j]

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
data1=data.iloc[:,:3]            
data2=data.iloc[:,4:]
X=np.hstack((data1,data2))
X=np.array(X)  
print(X.shape)
# Out:
# (2938, 21)

# %% [markdown]
# # Removing nan from Data

# %%
X=pd.DataFrame(X)                
m=X.mean()    
X=X.fillna(m)
count=X.isna().sum()    
X=np.array(X)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
y=data.iloc[:,3]                 
y=np.array(y)  
print(y.shape)
# Out:
# (2938,)

# %% [markdown]
# # Removing nan from Target

# %%
y=pd.DataFrame(y)               
y=y.fillna(np.mean(y))             
y=np.array(y)

# %% [markdown]
# # Train Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=4)   
print(X_train.shape,'   ',y_train.shape,'  ',X_test.shape,'  ',y_test.shape)
# Out:
# (2056, 21)     (2056, 1)    (882, 21)    (882, 1)

# %% [markdown]
# # Regression

# %%
clf=DecisionTreeRegressor(random_state=0)          
clf.fit(X_train,y_train)                                                        
predicted=clf.predict(X_test)
expected=y_test

# %% [markdown]
# # Mean Square Error

# %%
mse=0                                      
for i in range(y_test.shape[0]):
    mse+=(y_test[i]-predicted[i])**2
mse_=math.sqrt(mse//(y_test.shape[0]))
print(mse_)
# Out:
# 2.449489742783178
